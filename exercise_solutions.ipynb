# %% [markdown]
# # SQLite Python excercise

# %%
import sqlite3

# %% [markdown]
# ## Intro

# %% [markdown]
# Create DB

# %%
# database represented as a 'connection'
# new database is created if it does not exist on given name
con = sqlite3.connect("movie.db")

# %% [markdown]
# Database interface is called 'cursor'

# %%
cur = con.cursor()

# %% [markdown]
# The cursor allows us to interact with the database using SQL

# %%
cur.execute("CREATE TABLE movie (title, year, score)")

# %% [markdown]
# Add data:

# %%
cur.execute("""
    INSERT INTO movie VALUES
        ('Monty Python and the Holy Grail', 1975, 8.2),
        ('And Now for Something Completely Different', 1971, 7.5)
""")
con.commit() # changes must be committed

# %% [markdown]
# Query data:

# %%
res = cur.execute("SELECT * FROM movie")
res.fetchall()
# Out:
# [('Monty Python and the Holy Grail', 1975, 8.2),
#  ('And Now for Something Completely Different', 1971, 7.5)]

# %% [markdown]
# You can also add multiple rows using a one-liner:

# %%
data = [
    ("Monty Python Live at the Hollywood Bowl", 1982, 7.9),
    ("Monty Python's The Meaning of Life", 1983, 7.5),
    ("Monty Python's Life of Brian", 1979, 8.0),
]
cur.executemany("INSERT INTO movie VALUES(?, ?, ?)", data)
con.commit()

# %% [markdown]
# Notice that ? placeholders are used to bind data to the query. Always use placeholders instead of string formatting to bind Python values to SQL statements, to avoid SQL injection attacks.
#
# What is an SQL injection attack? Consider the following:

# %%
# let's imagine we ask a user for their information. Instead
# they give us the following data:
row = "('dmbfkl', 1,1);DROP TABLE movie"

cur.executescript(f"INSERT INTO movie VALUES {row}")

# %% [markdown]
# The 'DROP TABLE' injection has destroyed the table

# %%
try:
    cur.execute("SELECT * FROM movie")
except Exception as e:
    print(e)
# Out:
# no such table: movie

# %% [markdown]
# ## Excercise 1: load xlsx and store rows in a single sqlite table
#
# Data: Hus ostolaskut 22Q1

# %%
import pandas as pd

# %%
# read only 1000 rows, because the file is huge!
pd.read_excel("https://www.hus.fi/sites/default/files/2022-04/husin-ostolaskutiedot-q1-2022.xlsx", nrows = 1000)
# Out:
#                Nimi    Y-tunnus  Tulosyksikkö       Tulosyksikön nimi  \
# 0    HUS-kuntayhtymä  1567535-0         700.0  TILAKESKUKSEN HALLINTO
# 1    HUS-kuntayhtymä  1567535-0         710.0          YHTYMÄHALLINTO
# 2    HUS-kuntayhtymä  1567535-0         700.0  TILAKESKUKSEN HALLINTO
# 3    HUS-kuntayhtymä  1567535-0         710.0          YHTYMÄHALLINTO
# 4    HUS-kuntayhtymä  1567535-0         700.0  TILAKESKUKSEN HALLINTO
# ..               ...        ...           ...                     ...
# 995  HUS-kuntayhtymä  1567535-0         760.0         HUS LOGISTIIKKA
# 996  HUS-kuntayhtymä  1567535-0         710.0          YHTYMÄHALLINTO
# 997  HUS-kuntayhtymä  1567535-0         760.0         HUS LOGISTIIKKA
# 998  HUS-kuntayhtymä  1567535-0         760.0         HUS LOGISTIIKKA
# 999  HUS-kuntayhtymä  1567535-0         760.0         HUS LOGISTIIKKA
#
#      Vastuuyksikkö          Vastuuyksikön nimi  Palveluluokka Laskun päiväys  \
# 0          7002018       Vuokratilat, Helsinki         5501.0     24.03.2022
# 1          7103002              Tasekirjaukset         9999.0     24.03.2022
# 2          7002018       Vuokratilat, Helsinki         5501.0     01.01.2022
# 3          7103002              Tasekirjaukset         9999.0     01.01.2022
# 4          7002018       Vuokratilat, Helsinki         5501.0     01.01.2022
# ..             ...                         ...            ...            ...
# 995        7602014  Varasto, logistiikkakeskus         5501.0     19.01.2022
# 996        7103002              Tasekirjaukset         9999.0     19.01.2022
# 997        7602014  Varasto, logistiikkakeskus         5501.0     19.01.2022
# 998        7602014  Varasto, logistiikkakeskus         5501.0     19.01.2022
# 999        7602014  Varasto, logistiikkakeskus         5501.0     19.01.2022
#
#      Tosite numero  Ostotilaus numero  ...                 Tiliryhmän nimi  \
# 0            26462                NaN  ...  LÄMMITYS, SÄHKÖ, KAASU JA VESI
# 1            26462                NaN  ...    MUUT SAAMISET, LYHYTAIKAISET
# 2            23256                NaN  ...                         VUOKRAT
# 3            23256                NaN  ...    MUUT SAAMISET, LYHYTAIKAISET
# 4            23256                NaN  ...                         VUOKRAT
# ..             ...                ...  ...                             ...
# 995          24175        392217834.0  ...       LYHYTAIKAISET SIIRTOVELAT
# 996          24175                NaN  ...    MUUT SAAMISET, LYHYTAIKAISET
# 997          24049        392218055.0  ...       LYHYTAIKAISET SIIRTOVELAT
# 998          24049        392218055.0  ...       LYHYTAIKAISET SIIRTOVELAT
# 999          24049        392218055.0  ...       LYHYTAIKAISET SIIRTOVELAT
#
#     Tilin numero                  Tilin nimi               Toimittajan nimi  \
# 0         457020                       Sähkö  KIINTEISTÖ OY PASILANRAITIO 5
# 1         176024  Alv-saamiset, palautus 24%  KIINTEISTÖ OY PASILANRAITIO 5
# 2         480020        Toimitilojen vuokrat            HENRY INVESTMENT OY
# 3         176024  Alv-saamiset, palautus 24%            HENRY INVESTMENT OY
# 4         480020        Toimitilojen vuokrat            HENRY INVESTMENT OY
# ..           ...                         ...                            ...
# 995       257070        Varaston siirtovelka                  STERIPOLAR OY
# 996       176024  Alv-saamiset, palautus 24%                  STERIPOLAR OY
# 997       257070        Varaston siirtovelka                  STERIPOLAR OY
# 998       257070        Varaston siirtovelka                  STERIPOLAR OY
# 999       257070        Varaston siirtovelka                  STERIPOLAR OY
#
#     Toimittajan maakoodi  Toimittajan        y-tunnus ALV-rekisterinumero  \
# 0                     FI                    0550836-4          FI05508364
# 1                     FI                    0550836-4          FI05508364
# 2                     FI                    2922998-4          FI29229984
# 3                     FI                    2922998-4          FI29229984
# 4                     FI                    2922998-4          FI29229984
# ..                   ...                          ...                 ...
# 995                   FI                    0603924-8          FI06039248
# 996                   FI                    0603924-8          FI06039248
# 997                   FI                    0603924-8          FI06039248
# 998                   FI                    0603924-8          FI06039248
# 999                   FI                    0603924-8          FI06039248
#
#     Netto summa Alv summa Kokonais summa
# 0        290.24     69.66         359.90
# 1           NaN     69.66          69.66
# 2      14627.13   3510.51       18137.64
# 3           NaN   3510.51        3510.51
# 4       7300.00   1752.00        9052.00
# ..          ...       ...            ...
# 995      900.00    216.00        1116.00
# 996         NaN    216.00         216.00
# 997       19.50      4.68          24.18
# 998      650.00    156.00         806.00
# 999      940.00    225.60        1165.60
#
# [1000 rows x 24 columns]

# %%
#  your code here
df = pd.read_excel("https://www.hus.fi/sites/default/files/2022-04/husin-ostolaskutiedot-q1-2022.xlsx", nrows = 1000)
display(df.head(3))
display(df.columns)
print(f"Number of columns in data: {len(df.columns)}")

cur.execute("DROP TABLE IF EXISTS ostolasku")
cur.execute("CREATE TABLE ostolasku (Nimi, Y_tunnus, Tulosyksikko, Tulosyksikon_nimi, Vastuuyksikko, Vastuuyksikon_nimi,\
                                     Palveluluokka, Laskun_paivays, Tosite_numero, Ostotilaus numero, Sopimus_numero,\
                                     Tosite_paivamaara, Laskun_numero, Tiliryhma, Tiliryhman_nimi, Tilin_numero, Tilin_nimi,\
                                     Toimittajan_nimi, Toimittajan_maakoodi, Toimittajan_y_tunnus, ALV_rekisterinumero,\
                                     Netto_summa, Alv_summa, Kokonaissumma)")
cur.executemany("INSERT INTO ostolasku VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", df.values.tolist())
con.commit()

res = cur.execute("SELECT * FROM ostolasku")
res.fetchall()
# Out:
#              Nimi    Y-tunnus  Tulosyksikkö       Tulosyksikön nimi  \
# 0  HUS-kuntayhtymä  1567535-0         700.0  TILAKESKUKSEN HALLINTO
# 1  HUS-kuntayhtymä  1567535-0         710.0          YHTYMÄHALLINTO
# 2  HUS-kuntayhtymä  1567535-0         700.0  TILAKESKUKSEN HALLINTO
#
#    Vastuuyksikkö     Vastuuyksikön nimi  Palveluluokka Laskun päiväys  \
# 0        7002018  Vuokratilat, Helsinki         5501.0     24.03.2022
# 1        7103002         Tasekirjaukset         9999.0     24.03.2022
# 2        7002018  Vuokratilat, Helsinki         5501.0     01.01.2022
#
#    Tosite numero  Ostotilaus numero  ...                 Tiliryhmän nimi  \
# 0          26462                NaN  ...  LÄMMITYS, SÄHKÖ, KAASU JA VESI
# 1          26462                NaN  ...    MUUT SAAMISET, LYHYTAIKAISET
# 2          23256                NaN  ...                         VUOKRAT
#
#   Tilin numero                  Tilin nimi               Toimittajan nimi  \
# 0       457020                       Sähkö  KIINTEISTÖ OY PASILANRAITIO 5
# 1       176024  Alv-saamiset, palautus 24%  KIINTEISTÖ OY PASILANRAITIO 5
# 2       480020        Toimitilojen vuokrat            HENRY INVESTMENT OY
#
#   Toimittajan maakoodi  Toimittajan        y-tunnus ALV-rekisterinumero  \
# 0                   FI                    0550836-4          FI05508364
# 1                   FI                    0550836-4          FI05508364
# 2                   FI                    2922998-4          FI29229984
#
#   Netto summa Alv summa Kokonais summa
# 0      290.24     69.66         359.90
# 1         NaN     69.66          69.66
# 2    14627.13   3510.51       18137.64
#
# [3 rows x 24 columns]
# Index(['Nimi ', 'Y-tunnus', 'Tulosyksikkö', 'Tulosyksikön nimi',
#        'Vastuuyksikkö', 'Vastuuyksikön nimi', 'Palveluluokka',
#        'Laskun päiväys', 'Tosite numero', 'Ostotilaus numero',
#        'Sopimus numero', 'Tosite päivämäärä', 'Laskun numero', 'Tiliryhmä',
#        'Tiliryhmän nimi', 'Tilin numero', 'Tilin nimi', 'Toimittajan nimi',
#        'Toimittajan maakoodi', 'Toimittajan        y-tunnus',
#        'ALV-rekisterinumero', 'Netto summa', 'Alv summa', 'Kokonais summa'],
#       dtype='object')
# Number of columns in data: 24
# [('HUS-kuntayhtymä',
#   '1567535-0',
#   700.0,
#   'TILAKESKUKSEN HALLINTO',
#   7002018,
#   'Vuokratilat, Helsinki',
#   5501.0,
#   '24.03.2022',
#   26462,
#   None,
#   None,
#   '24.03.2022',
#   '000000001074',
#   'T457',
#   'LÄMMITYS, SÄHKÖ, KAASU JA VESI',
#   457020,
#   'Sähkö',
#   'KIINTEISTÖ OY PASILANRAITIO 5',
#   'FI',
#   '0550836-4',
#   'FI05508364',
#   290.24,
#   69.66,
#   359.9),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '24.03.2022',
#   26462,
#   None,
#   None,
#   '24.03.2022',
#   '000000001074',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'KIINTEISTÖ OY PASILANRAITIO 5',
#   'FI',
#   '0550836-4',
#   'FI05508364',
#   None,
#   69.66,
#   69.66),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   700.0,
#   'TILAKESKUKSEN HALLINTO',
#   7002018,
#   'Vuokratilat, Helsinki',
#   5501.0,
#   '01.01.2022',
#   23256,
#   None,
#   None,
#   '01.01.2022',
#   '000000008927',
#   'T480',
#   'VUOKRAT',
#   480020,
#   'Toimitilojen vuokrat',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   14627.13,
#   3510.51,
#   18137.64),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.01.2022',
#   23256,
#   None,
#   None,
#   '01.01.2022',
#   '000000008927',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   None,
#   3510.51,
#   3510.51),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   700.0,
#   'TILAKESKUKSEN HALLINTO',
#   7002018,
#   'Vuokratilat, Helsinki',
#   5501.0,
#   '01.01.2022',
#   23256,
#   None,
#   None,
#   '01.01.2022',
#   '000000008995',
#   'T480',
#   'VUOKRAT',
#   480020,
#   'Toimitilojen vuokrat',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   7300.0,
#   1752.0,
#   9052.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.01.2022',
#   23256,
#   None,
#   None,
#   '01.01.2022',
#   '000000008995',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   None,
#   1752.0,
#   1752.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   700.0,
#   'TILAKESKUKSEN HALLINTO',
#   7002018,
#   'Vuokratilat, Helsinki',
#   5501.0,
#   '01.02.2022',
#   24329,
#   None,
#   None,
#   '01.02.2022',
#   '000000009080',
#   'T480',
#   'VUOKRAT',
#   480020,
#   'Toimitilojen vuokrat',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   7300.0,
#   1752.0,
#   9052.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.02.2022',
#   24329,
#   None,
#   None,
#   '01.02.2022',
#   '000000009080',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   None,
#   1752.0,
#   1752.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   700.0,
#   'TILAKESKUKSEN HALLINTO',
#   7002018,
#   'Vuokratilat, Helsinki',
#   5501.0,
#   '01.02.2022',
#   24329,
#   None,
#   None,
#   '01.02.2022',
#   '000000009092',
#   'T480',
#   'VUOKRAT',
#   480020,
#   'Toimitilojen vuokrat',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   15136.86,
#   3632.85,
#   18769.71),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.02.2022',
#   24329,
#   None,
#   None,
#   '01.02.2022',
#   '000000009092',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   None,
#   3632.85,
#   3632.85),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   700.0,
#   'TILAKESKUKSEN HALLINTO',
#   7002018,
#   'Vuokratilat, Helsinki',
#   5501.0,
#   '01.03.2022',
#   25221,
#   None,
#   None,
#   '01.03.2022',
#   '000000009102',
#   'T480',
#   'VUOKRAT',
#   480020,
#   'Toimitilojen vuokrat',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   15136.86,
#   3632.85,
#   18769.71),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.03.2022',
#   25221,
#   None,
#   None,
#   '01.03.2022',
#   '000000009102',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   None,
#   3632.85,
#   3632.85),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   700.0,
#   'TILAKESKUKSEN HALLINTO',
#   7002018,
#   'Vuokratilat, Helsinki',
#   5501.0,
#   '01.03.2022',
#   25221,
#   None,
#   None,
#   '01.03.2022',
#   '000000009119',
#   'T480',
#   'VUOKRAT',
#   480020,
#   'Toimitilojen vuokrat',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   7300.0,
#   1752.0,
#   9052.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.03.2022',
#   25221,
#   None,
#   None,
#   '01.03.2022',
#   '000000009119',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'HENRY INVESTMENT OY',
#   'FI',
#   '2922998-4',
#   'FI29229984',
#   None,
#   1752.0,
#   1752.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   777.0,
#   'MONIPALVELUALUE 5',
#   7770003,
#   'Ostopalvelut monipalvelualue 5, Ruokapalvelut',
#   5501.0,
#   '14.02.2022',
#   25109,
#   None,
#   None,
#   '14.02.2022',
#   '00000005',
#   'T490',
#   'MUUT TOIMINTAKULUT ILMAN VUOKRIA',
#   494000,
#   'Liiketoiminnan muut kulut',
#   'TIKKURILA-GRILLI OY',
#   'FI',
#   '2768040-5',
#   'FI27680405',
#   4.03,
#   0.97,
#   5.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   777.0,
#   'MONIPALVELUALUE 5',
#   7770003,
#   'Ostopalvelut monipalvelualue 5, Ruokapalvelut',
#   5501.0,
#   '14.02.2022',
#   25109,
#   None,
#   None,
#   '14.02.2022',
#   '00000005',
#   'T441',
#   'MAJOITUS- JA RAVITSEMISPALVELUT',
#   441000,
#   'Potilasruokailu',
#   'TIKKURILA-GRILLI OY',
#   'FI',
#   '2768040-5',
#   'FI27680405',
#   17.54,
#   2.46,
#   20.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   777.0,
#   'MONIPALVELUALUE 5',
#   7770003,
#   'Ostopalvelut monipalvelualue 5, Ruokapalvelut',
#   5501.0,
#   '14.02.2022',
#   25109,
#   None,
#   None,
#   '14.02.2022',
#   '00000005',
#   'T441',
#   'MAJOITUS- JA RAVITSEMISPALVELUT',
#   441002,
#   'Henkilökunnan työpaikkaruokailutuki',
#   'TIKKURILA-GRILLI OY',
#   'FI',
#   '2768040-5',
#   'FI27680405',
#   3.25,
#   0.45,
#   3.7),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '14.02.2022',
#   25109,
#   None,
#   None,
#   '14.02.2022',
#   '00000005',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176014,
#   'Alv-saamiset, palautus 14%',
#   'TIKKURILA-GRILLI OY',
#   'FI',
#   '2768040-5',
#   'FI27680405',
#   None,
#   0.45,
#   0.45),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '14.02.2022',
#   25109,
#   None,
#   None,
#   '14.02.2022',
#   '00000005',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176014,
#   'Alv-saamiset, palautus 14%',
#   'TIKKURILA-GRILLI OY',
#   'FI',
#   '2768040-5',
#   'FI27680405',
#   None,
#   2.46,
#   2.46),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '14.02.2022',
#   25109,
#   None,
#   None,
#   '14.02.2022',
#   '00000005',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'TIKKURILA-GRILLI OY',
#   'FI',
#   '2768040-5',
#   'FI27680405',
#   None,
#   0.97,
#   0.97),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   121.0,
#   'VATSAKESKUS',
#   1212004,
#   'Dialyysihoitokeskus KiDi, Kirurginen sairaala',
#   2602.0,
#   '17.02.2022',
#   25071,
#   None,
#   None,
#   '17.02.2022',
#   '0000029276/2022',
#   'B2325',
#   'LAHJOITUSRAHASTOJEN PÄÄOMAT, HUS',
#   232500,
#   'Lahjoitusrahastojen pääomat',
#   'GRENKELEASING OY',
#   'FI',
#   '2170416-2',
#   'FI21704162',
#   25.0,
#   6.0,
#   31.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '17.02.2022',
#   25071,
#   None,
#   None,
#   '17.02.2022',
#   '0000029276/2022',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'GRENKELEASING OY',
#   'FI',
#   '2170416-2',
#   'FI21704162',
#   None,
#   6.0,
#   6.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   121.0,
#   'VATSAKESKUS',
#   1210002,
#   'Erikoistuvat lääkärit, Vatsakeskus',
#   2602.0,
#   '02.01.2022',
#   25672,
#   None,
#   None,
#   '01.03.2022',
#   '000003001',
#   'T444',
#   'KOULUTUS JA TERVEYSPALVELUT',
#   444011,
#   'Lääkärihenkilökunnan koulutus',
#   'AO FOUNDATION',
#   'CH',
#   None,
#   None,
#   1610.0,
#   0.0,
#   1610.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   121.0,
#   'VATSAKESKUS',
#   1210003,
#   'Runkokoulutettavat lääkärit, kirurgia',
#   2602.0,
#   '02.01.2022',
#   25117,
#   None,
#   None,
#   '22.02.2022',
#   '000003003',
#   'T444',
#   'KOULUTUS JA TERVEYSPALVELUT',
#   444011,
#   'Lääkärihenkilökunnan koulutus',
#   'AO FOUNDATION',
#   'CH',
#   None,
#   None,
#   1610.0,
#   0.0,
#   1610.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   121.0,
#   'VATSAKESKUS',
#   1210003,
#   'Runkokoulutettavat lääkärit, kirurgia',
#   2602.0,
#   '23.02.2022',
#   25672,
#   None,
#   None,
#   '01.03.2022',
#   '000003158',
#   'T444',
#   'KOULUTUS JA TERVEYSPALVELUT',
#   444011,
#   'Lääkärihenkilökunnan koulutus',
#   'AO FOUNDATION',
#   'CH',
#   None,
#   None,
#   1610.0,
#   0.0,
#   1610.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   116.0,
#   'SYDÄN- JA KEUHKOKESKUS',
#   1163002,
#   'Sydänkirurgian erikoistuvat lääkärit',
#   2602.0,
#   '03.03.2022',
#   25647,
#   None,
#   None,
#   '04.03.2022',
#   '000003218',
#   'T444',
#   'KOULUTUS JA TERVEYSPALVELUT',
#   444011,
#   'Lääkärihenkilökunnan koulutus',
#   'AO FOUNDATION',
#   'CH',
#   None,
#   None,
#   1610.0,
#   0.0,
#   1610.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   620.0,
#   'PORVOO OPERATIIVINEN TULOSYKSIKKÖ',
#   6202008,
#   'Porvoo kirurgia',
#   2602.0,
#   '16.03.2022',
#   26152,
#   None,
#   None,
#   '17.03.2022',
#   '000003332',
#   'T444',
#   'KOULUTUS JA TERVEYSPALVELUT',
#   444011,
#   'Lääkärihenkilökunnan koulutus',
#   'AO FOUNDATION',
#   'CH',
#   None,
#   None,
#   1610.0,
#   0.0,
#   1610.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7104020,
#   'Tutkimushankkeet, ulkopuolinen rahoitus, HUS Yhteiset',
#   9999.0,
#   '14.03.2022',
#   25805,
#   None,
#   None,
#   '15.03.2022',
#   '00000988',
#   'T434',
#   'TOIMISTO- JA ASIANTUNTIJAPALVELUT',
#   434030,
#   'ICT-palvelut',
#   'TTOPSTART B.V.',
#   'NL',
#   None,
#   'NL820871175B01',
#   13500.0,
#   0.0,
#   13500.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '14.03.2022',
#   25805,
#   None,
#   None,
#   '15.03.2022',
#   '00000988',
#   'B2550',
#   'LYHYTAIKAISET MUUT VELAT',
#   255024,
#   'Tilitettävät alv, 24 %',
#   'TTOPSTART B.V.',
#   'NL',
#   None,
#   'NL820871175B01',
#   None,
#   -3240.0,
#   -3240.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '14.03.2022',
#   25805,
#   None,
#   None,
#   '15.03.2022',
#   '00000988',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'TTOPSTART B.V.',
#   'NL',
#   None,
#   'NL820871175B01',
#   None,
#   3240.0,
#   3240.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   380.0,
#   20.0,
#   400.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   190.0,
#   10.0,
#   200.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122008,
#   'Myyrmäen mielialahäiriöpoliklinikka',
#   2601.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   522.5,
#   27.5,
#   550.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   1026.0,
#   54.0,
#   1080.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2125004,
#   'Nuorten yleissairaalapsykiatrian yksikkö',
#   None,
#   '06.12.2021',
#   23398,
#   None,
#   None,
#   '06.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'PSYKOLOGIPALVELU KIRSI PESSI',
#   'FI',
#   '2799304-9',
#   'FI27993049',
#   361.0,
#   19.0,
#   380.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   None,
#   27.5,
#   27.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '07.12.2021',
#   23599,
#   None,
#   None,
#   '07.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   None,
#   20.0,
#   20.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   None,
#   54.0,
#   54.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   None,
#   10.0,
#   10.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   None,
#   None,
#   2127018,
#   'Psykiatrian hallinto, Hyvinkää',
#   None,
#   '07.12.2021',
#   23599,
#   None,
#   None,
#   '07.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   418.0,
#   22.0,
#   440.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '07.12.2021',
#   23599,
#   None,
#   None,
#   '07.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   475.0,
#   25.0,
#   500.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   190.0,
#   10.0,
#   200.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   380.0,
#   20.0,
#   400.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2126003,
#   'Psykologiyksikkö, Akuutti',
#   2601.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   None,
#   22.0,
#   22.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '07.12.2021',
#   23599,
#   None,
#   None,
#   '07.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   None,
#   25.0,
#   25.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   None,
#   20.0,
#   20.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   None,
#   10.0,
#   10.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   342.0,
#   18.0,
#   360.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '07.12.2021',
#   23599,
#   None,
#   None,
#   '07.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   256.5,
#   13.5,
#   270.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   503.5,
#   26.5,
#   530.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   95.0,
#   5.0,
#   100.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   None,
#   18.0,
#   18.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '07.12.2021',
#   23599,
#   None,
#   None,
#   '07.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   None,
#   13.5,
#   13.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   None,
#   26.5,
#   26.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   None,
#   5.0,
#   5.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   522.5,
#   27.5,
#   550.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121007,
#   'Tikkurilan akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   940.5,
#   49.5,
#   990.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   None,
#   27.5,
#   27.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   None,
#   49.5,
#   49.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   None,
#   5.0,
#   5.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   None,
#   None,
#   2127018,
#   'Psykiatrian hallinto, Hyvinkää',
#   None,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   95.0,
#   5.0,
#   100.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121007,
#   'Tikkurilan akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   209.0,
#   11.0,
#   220.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121007,
#   'Tikkurilan akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   190.0,
#   10.0,
#   200.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122004,
#   'Matinkylän mielialahäiriöpoliklinikka',
#   2601.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   342.0,
#   18.0,
#   360.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2123011,
#   'Tikkurilan psykoosipoliklinikka',
#   2601.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   380.0,
#   20.0,
#   400.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '02.12.2021',
#   23363,
#   None,
#   None,
#   '01.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'AL KAUPPI',
#   'FI',
#   '1494648-9',
#   'FI14946489',
#   None,
#   18.0,
#   18.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   None,
#   20.0,
#   20.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '22.01.2022',
#   24306,
#   None,
#   None,
#   '22.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   None,
#   11.0,
#   11.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '31.12.2021',
#   23724,
#   None,
#   None,
#   '01.01.2022',
#   '00001',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIAPALVELU SARI HARJU',
#   'FI',
#   '2772327-6',
#   'FI27723276',
#   None,
#   10.0,
#   10.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2120023,
#   'Lohjan psykiatrian poliklinikat',
#   2601.0,
#   '02.03.2022',
#   25673,
#   None,
#   None,
#   '02.03.2022',
#   '0000105306',
#   'T444',
#   'KOULUTUS JA TERVEYSPALVELUT',
#   444014,
#   'Muun henkilöstön koulutus',
#   'HELSINGIN SEUDUN KESÄYLIOPISTOSÄÄTIÖ',
#   'FI',
#   '0116513-0',
#   'FI01165130',
#   1875.0,
#   0.0,
#   1875.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2120023,
#   'Lohjan psykiatrian poliklinikat',
#   2601.0,
#   '31.12.2021',
#   23883,
#   None,
#   None,
#   '01.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'SUONSYRJÄ RIIKKA',
#   'FI',
#   '2613044-4',
#   'FI26130444',
#   228.0,
#   12.0,
#   240.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2120025,
#   'Psykiatrian hallinto, Hyvinkää',
#   2601.0,
#   '18.01.2022',
#   24099,
#   None,
#   None,
#   '18.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   380.0,
#   20.0,
#   400.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2120025,
#   'Psykiatrian hallinto, Hyvinkää',
#   2601.0,
#   '28.02.2022',
#   25848,
#   None,
#   None,
#   '01.03.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIA TOIVON OVI',
#   'FI',
#   '2705437-5',
#   'FI27054375',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '01.02.2022',
#   24695,
#   None,
#   None,
#   '31.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'ALA-TUUHONEN KATRI',
#   'FI',
#   '2006386-9',
#   'FI20063869',
#   313.5,
#   16.5,
#   330.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '03.01.2022',
#   23810,
#   None,
#   None,
#   '03.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RISTEX OY',
#   'FI',
#   '0113441-4',
#   'FI01134414',
#   95.0,
#   5.0,
#   100.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '29.12.2021',
#   23619,
#   None,
#   None,
#   '29.12.2021',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIATUULET',
#   'FI',
#   '2467577-4',
#   'FI24675774',
#   190.0,
#   10.0,
#   200.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121007,
#   'Tikkurilan akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '20.12.2021',
#   23379,
#   None,
#   None,
#   '20.12.2021',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'FADJUKOV SARI PSYKOTERAPEUTTI',
#   'FI',
#   '1549073-5',
#   'FI15490735',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '03.03.2022',
#   25850,
#   None,
#   None,
#   '03.03.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   760.0,
#   40.0,
#   800.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '04.02.2022',
#   25371,
#   None,
#   None,
#   '01.02.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'ROIVAINEN HELENA TMI',
#   'FI',
#   '1777243-7',
#   'FI17772437',
#   513.0,
#   27.0,
#   540.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2125002,
#   'Matinkylän nuorisopsykiatrian poliklinikka',
#   None,
#   '16.12.2021',
#   23606,
#   None,
#   None,
#   '16.12.2021',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'PSYKOTERAPEUTTI MINNA GERRETT',
#   'FI',
#   '2853924-3',
#   'FI28539243',
#   256.5,
#   13.5,
#   270.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.02.2022',
#   24695,
#   None,
#   None,
#   '31.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'ALA-TUUHONEN KATRI',
#   'FI',
#   '2006386-9',
#   'FI20063869',
#   None,
#   16.5,
#   16.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '03.01.2022',
#   23810,
#   None,
#   None,
#   '03.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RISTEX OY',
#   'FI',
#   '0113441-4',
#   'FI01134414',
#   None,
#   5.0,
#   5.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '03.03.2022',
#   25850,
#   None,
#   None,
#   '03.03.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   None,
#   40.0,
#   40.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   24099,
#   None,
#   None,
#   '18.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   None,
#   20.0,
#   20.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '20.12.2021',
#   23379,
#   None,
#   None,
#   '20.12.2021',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'FADJUKOV SARI PSYKOTERAPEUTTI',
#   'FI',
#   '1549073-5',
#   'FI15490735',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '28.02.2022',
#   25848,
#   None,
#   None,
#   '01.03.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIA TOIVON OVI',
#   'FI',
#   '2705437-5',
#   'FI27054375',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '29.12.2021',
#   23619,
#   None,
#   None,
#   '29.12.2021',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIATUULET',
#   'FI',
#   '2467577-4',
#   'FI24675774',
#   None,
#   10.0,
#   10.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '18.01.2022',
#   24099,
#   None,
#   None,
#   '18.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   380.0,
#   20.0,
#   400.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '28.02.2022',
#   25848,
#   None,
#   None,
#   '01.03.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIA TOIVON OVI',
#   'FI',
#   '2705437-5',
#   'FI27054375',
#   95.0,
#   5.0,
#   100.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121007,
#   'Tikkurilan akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '03.01.2022',
#   23810,
#   None,
#   None,
#   '03.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RISTEX OY',
#   'FI',
#   '0113441-4',
#   'FI01134414',
#   256.5,
#   13.5,
#   270.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121007,
#   'Tikkurilan akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '29.12.2021',
#   23619,
#   None,
#   None,
#   '29.12.2021',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIATUULET',
#   'FI',
#   '2467577-4',
#   'FI24675774',
#   190.0,
#   10.0,
#   200.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121013,
#   'Psykiatrian konsultaatiopoliklinikka',
#   2601.0,
#   '01.02.2022',
#   24695,
#   None,
#   None,
#   '31.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'ALA-TUUHONEN KATRI',
#   'FI',
#   '2006386-9',
#   'FI20063869',
#   570.0,
#   30.0,
#   600.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122006,
#   'Leppävaaran mielialahäiriöpoliklinikka',
#   2601.0,
#   '20.12.2021',
#   23379,
#   None,
#   None,
#   '20.12.2021',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'FADJUKOV SARI PSYKOTERAPEUTTI',
#   'FI',
#   '1549073-5',
#   'FI15490735',
#   85.5,
#   4.5,
#   90.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '03.03.2022',
#   25850,
#   None,
#   None,
#   '03.03.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   503.5,
#   26.5,
#   530.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.02.2022',
#   24695,
#   None,
#   None,
#   '31.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'ALA-TUUHONEN KATRI',
#   'FI',
#   '2006386-9',
#   'FI20063869',
#   None,
#   30.0,
#   30.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '03.01.2022',
#   23810,
#   None,
#   None,
#   '03.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RISTEX OY',
#   'FI',
#   '0113441-4',
#   'FI01134414',
#   None,
#   13.5,
#   13.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '03.03.2022',
#   25850,
#   None,
#   None,
#   '03.03.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   None,
#   26.5,
#   26.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   24099,
#   None,
#   None,
#   '18.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   None,
#   20.0,
#   20.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '20.12.2021',
#   23379,
#   None,
#   None,
#   '20.12.2021',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'FADJUKOV SARI PSYKOTERAPEUTTI',
#   'FI',
#   '1549073-5',
#   'FI15490735',
#   None,
#   4.5,
#   4.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '28.02.2022',
#   25848,
#   None,
#   None,
#   '01.03.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIA TOIVON OVI',
#   'FI',
#   '2705437-5',
#   'FI27054375',
#   None,
#   5.0,
#   5.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '29.12.2021',
#   23619,
#   None,
#   None,
#   '29.12.2021',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIATUULET',
#   'FI',
#   '2467577-4',
#   'FI24675774',
#   None,
#   10.0,
#   10.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2120025,
#   'Psykiatrian hallinto, Hyvinkää',
#   2601.0,
#   '28.02.2022',
#   25848,
#   None,
#   None,
#   '01.03.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIA TOIVON OVI',
#   'FI',
#   '2705437-5',
#   'FI27054375',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '01.02.2022',
#   24695,
#   None,
#   None,
#   '31.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'ALA-TUUHONEN KATRI',
#   'FI',
#   '2006386-9',
#   'FI20063869',
#   456.0,
#   24.0,
#   480.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '18.01.2022',
#   24099,
#   None,
#   None,
#   '18.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   380.0,
#   20.0,
#   400.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121007,
#   'Tikkurilan akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '29.12.2021',
#   23619,
#   None,
#   None,
#   '29.12.2021',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIATUULET',
#   'FI',
#   '2467577-4',
#   'FI24675774',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '03.03.2022',
#   25850,
#   None,
#   None,
#   '03.03.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   285.0,
#   15.0,
#   300.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2124010,
#   'Jorvin geropsykiatrian poliklinikka',
#   2601.0,
#   '03.01.2022',
#   23810,
#   None,
#   None,
#   '03.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RISTEX OY',
#   'FI',
#   '0113441-4',
#   'FI01134414',
#   85.5,
#   4.5,
#   90.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '01.02.2022',
#   24695,
#   None,
#   None,
#   '31.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'ALA-TUUHONEN KATRI',
#   'FI',
#   '2006386-9',
#   'FI20063869',
#   None,
#   24.0,
#   24.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '03.01.2022',
#   23810,
#   None,
#   None,
#   '03.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RISTEX OY',
#   'FI',
#   '0113441-4',
#   'FI01134414',
#   None,
#   4.5,
#   4.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '03.03.2022',
#   25850,
#   None,
#   None,
#   '03.03.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   24099,
#   None,
#   None,
#   '18.01.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'RK-PSYKOTERAPIA',
#   'FI',
#   '2701271-4',
#   'FI27012714',
#   None,
#   20.0,
#   20.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '28.02.2022',
#   25848,
#   None,
#   None,
#   '01.03.2022',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIA TOIVON OVI',
#   'FI',
#   '2705437-5',
#   'FI27054375',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '29.12.2021',
#   23619,
#   None,
#   None,
#   '29.12.2021',
#   '00002',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176001,
#   'Alv-saamiset, laskennallinen palautus 5%',
#   'TERAPIATUULET',
#   'FI',
#   '2467577-4',
#   'FI24675774',
#   None,
#   15.0,
#   15.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2121004,
#   'Matinkylän akuuttipsykiatrian poliklinikka',
#   2601.0,
#   '03.01.2022',
#   23810,
#   None,
#   None,
#   '03.01.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'RISTEX OY',
#   'FI',
#   '0113441-4',
#   'FI01134414',
#   190.0,
#   10.0,
#   200.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '03.03.2022',
#   25850,
#   None,
#   None,
#   '03.03.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'LEINONEN ARI',
#   'FI',
#   '1905372-7',
#   'FI19053727',
#   95.0,
#   5.0,
#   100.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '28.02.2022',
#   25848,
#   None,
#   None,
#   '01.03.2022',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIA TOIVON OVI',
#   'FI',
#   '2705437-5',
#   'FI27054375',
#   171.0,
#   9.0,
#   180.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   212.0,
#   'AIVOKESKUS',
#   2122009,
#   'Tikkurilan mielialahäiriöpoliklinikka',
#   2601.0,
#   '29.12.2021',
#   23619,
#   None,
#   None,
#   '29.12.2021',
#   '00002',
#   'T430',
#   'SAIRAANHOIDOLLISTEN PALVELUJEN OSTOT',
#   430032,
#   'Palvelusetelien ostot',
#   'TERAPIATUULET',
#   'FI',
#   '2467577-4',
#   'FI24675774',
#   95.0,
#   5.0,
#   100.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
# ...
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   45.0,
#   10.8,
#   55.8),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   24046,
#   392217153,
#   3701436.0,
#   '20.01.2022',
#   '000299255',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   73.2,
#   17.568,
#   90.768),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   24046,
#   392217153,
#   3701436.0,
#   '20.01.2022',
#   '000299255',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   127.4,
#   30.576,
#   157.976),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   24046,
#   None,
#   None,
#   '20.01.2022',
#   '000299255',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   7.8,
#   7.8),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   24046,
#   None,
#   None,
#   '20.01.2022',
#   '000299255',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   89.4,
#   89.4),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   24046,
#   None,
#   None,
#   '20.01.2022',
#   '000299255',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   189.59,
#   189.59),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   24023,
#   392217562,
#   3701026.0,
#   '19.01.2022',
#   '000299281',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   745.0,
#   178.8,
#   923.8),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   24023,
#   392217562,
#   3701026.0,
#   '19.01.2022',
#   '000299281',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   537.0,
#   128.88,
#   665.88),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   24023,
#   392217562,
#   3701026.0,
#   '19.01.2022',
#   '000299281',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   137.7,
#   33.048,
#   170.748),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   24023,
#   None,
#   None,
#   '19.01.2022',
#   '000299281',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   128.88,
#   128.88),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   24023,
#   None,
#   None,
#   '19.01.2022',
#   '000299281',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   178.8,
#   178.8),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217563,
#   3700325.0,
#   '18.01.2022',
#   '000299282',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   21.0,
#   5.04,
#   26.04),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217563,
#   3700325.0,
#   '18.01.2022',
#   '000299282',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   277.5,
#   66.6,
#   344.1),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217563,
#   3700325.0,
#   '18.01.2022',
#   '000299282',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   476.0,
#   114.24,
#   590.24),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217563,
#   3700325.0,
#   '18.01.2022',
#   '000299282',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   275.0,
#   66.0,
#   341.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217563,
#   3700325.0,
#   '18.01.2022',
#   '000299282',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   1656.0,
#   397.44,
#   2053.44),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217563,
#   3700325.0,
#   '18.01.2022',
#   '000299282',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   82.3,
#   19.752,
#   102.05199999999999),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217563,
#   3700325.0,
#   '18.01.2022',
#   '000299282',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   1088.0,
#   261.12,
#   1349.12),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217563,
#   3700325.0,
#   '18.01.2022',
#   '000299282',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   67.6,
#   16.224,
#   83.824),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299282',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   5.04,
#   5.04),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299282',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   66.0,
#   66.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299282',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   66.6,
#   66.6),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299282',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   114.24,
#   114.24),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299282',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   397.45,
#   397.45),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217561,
#   3701059.0,
#   '18.01.2022',
#   '000299284',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   33120.0,
#   7948.8,
#   41068.8),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299284',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   7948.8,
#   7948.8),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217564,
#   3700325.0,
#   '18.01.2022',
#   '000299289',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   298.0,
#   71.52,
#   369.52),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217564,
#   3700325.0,
#   '18.01.2022',
#   '000299289',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   770.0,
#   184.8,
#   954.8),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217564,
#   3700325.0,
#   '18.01.2022',
#   '000299289',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   36.0,
#   8.64,
#   44.64),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299289',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   71.52,
#   71.52),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299289',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   184.8,
#   184.8),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217565,
#   3701026.0,
#   '18.01.2022',
#   '000299292',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   70.5,
#   16.92,
#   87.42),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217565,
#   3701026.0,
#   '18.01.2022',
#   '000299292',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   1185.0,
#   284.4,
#   1469.4),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217565,
#   3701026.0,
#   '18.01.2022',
#   '000299292',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   12.5,
#   3.0,
#   15.5),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217565,
#   3701026.0,
#   '18.01.2022',
#   '000299292',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   64.6,
#   15.504,
#   80.104),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '18.01.2022',
#   23986,
#   392217565,
#   3701026.0,
#   '18.01.2022',
#   '000299292',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   13.0,
#   3.12,
#   16.12),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299292',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   3.0,
#   3.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299292',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   16.92,
#   16.92),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '18.01.2022',
#   23986,
#   None,
#   None,
#   '18.01.2022',
#   '000299292',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   284.4,
#   284.4),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   116.0,
#   'SYDÄN- JA KEUHKOKESKUS',
#   1162021,
#   'Tilapäinen Koronaosasto, Kirurginen sairaala',
#   2602.0,
#   '18.01.2022',
#   24008,
#   392217705,
#   None,
#   '18.01.2022',
#   '000299305',
#   'T450',
#   'TOIMISTOTARVIKKEET JA KIRJALLISUUS',
#   450010,
#   'Toimistotarvikkeet',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   -431.2,
#   163.968,
#   -267.23199999999997),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '19.01.2022',
#   24175,
#   392217834,
#   None,
#   '26.01.2022',
#   '000299350',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   900.0,
#   216.0,
#   1116.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   710.0,
#   'YHTYMÄHALLINTO',
#   7103002,
#   'Tasekirjaukset',
#   9999.0,
#   '19.01.2022',
#   24175,
#   None,
#   None,
#   '26.01.2022',
#   '000299350',
#   'A1760',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   176024,
#   'Alv-saamiset, palautus 24%',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   None,
#   216.0,
#   216.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '19.01.2022',
#   24049,
#   392218055,
#   3700543.0,
#   '20.01.2022',
#   '000299364',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   19.5,
#   4.68,
#   24.18),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '19.01.2022',
#   24049,
#   392218055,
#   3700543.0,
#   '20.01.2022',
#   '000299364',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   650.0,
#   156.0,
#   806.0),
#  ('HUS-kuntayhtymä',
#   '1567535-0',
#   760.0,
#   'HUS LOGISTIIKKA',
#   7602014,
#   'Varasto, logistiikkakeskus',
#   5501.0,
#   '19.01.2022',
#   24049,
#   392218055,
#   3700543.0,
#   '20.01.2022',
#   '000299364',
#   'B2570',
#   'LYHYTAIKAISET SIIRTOVELAT',
#   257070,
#   'Varaston siirtovelka',
#   'STERIPOLAR OY',
#   'FI',
#   '0603924-8',
#   'FI06039248',
#   940.0,
#   225.6,
#   1165.6)]

# %% [markdown]
# ## Exercise 2: There is a change!
#
# A provider called 'HENRY INVESTMENT OY' changes their company name to 'HENRY CAPITAL OY'. Perform the change on the records in the database.

# %%
# your code here

old_name = "HENRY INVESTMENT OY"
new_name = "HENRY CAPITAL OY"

print(f"*****  NUMBER OF ROWS WITH NAME '{new_name}' BEFORE UPDATE *****")
res = cur.execute("SELECT COUNT(*) FROM ostolasku WHERE Toimittajan_nimi = ?", (new_name,))
print(res.fetchall())

update_sql = "UPDATE ostolasku SET Toimittajan_nimi = ? WHERE Toimittajan_nimi = ?"
cur.execute(update_sql, (new_name, old_name))
con.commit()

res = cur.execute("select changes(),total_changes()");
print(f"\n\n... {res.fetchall()[0][0]} rows updated!\n\n")

print(f"*****  NUMBER OF ROWS WITH NAME '{new_name}' AFTER UPDATE *****")
res = cur.execute("SELECT COUNT(*) FROM ostolasku WHERE Toimittajan_nimi = ?", (new_name,))
display(res.fetchall())
# Out:
# *****  NUMBER OF ROWS WITH NAME 'HENRY CAPITAL OY' BEFORE UPDATE *****
# [(0,)]
#
#
# ... 12 rows updated!
#
#
# *****  NUMBER OF ROWS WITH NAME 'HENRY CAPITAL OY' AFTER UPDATE *****
# [(12,)]

# %% [markdown]
# ## Exercise 3: Time for normalization!
#
# From the previous example, you may have noticed how impractical it is to have all data in single master table. There is a lot of duplicate information risking breaking the data in face of change, and all operations need to handle the whole table and are thus very expensive. This is why normalization is needed.
#
# Normalization means breaking the table into entities and relations. The fundamental principle is to write each unit of information only once in the database, except for keys (IDs). There are exceptions, but this is what the aim is, usually.
#
# First, perform entity relationship modelling of the table (pen-and-paper or for example using https://erdplus.com). What are primary and foreign keys, attributes and constraints for the tables? Are the relations one-to-one or one-to-many?
#
# Then, create and fill the tables according the ER model.

# %%
# your code here

display(df.iloc[:5, 6:].head(3))
#display(df['Tulosyksikkö'].isna().sum())
#display(df['Tulosyksikkö'].drop_duplicates())

# CREATE AND FILL TABLE organisaatio
cur.execute("DROP TABLE IF EXISTS organisaatio")
cur.execute("CREATE TABLE organisaatio (organisaatio_y_tunnus VARCHAR (9) PRIMARY KEY, organisaatio_nimi VARCHAR)")
con.commit()
cur.executemany("INSERT INTO organisaatio VALUES(?, ?)", df.loc[:, ["Y-tunnus","Nimi "]].drop_duplicates().values.tolist())
con.commit()
res = cur.execute("SELECT * FROM organisaatio")
display(res.fetchall())
res = cur.execute("SELECT count(*) FROM organisaatio")
print (f"*****  ORGANISAATIO: {res.fetchall()[0][0]} rows inserted  *****\n\n")

# CREATE AND FILL TABLE tulosyksikko
cur.execute("DROP TABLE IF EXISTS tulosyksikko")
cur.execute("CREATE TABLE tulosyksikko (tulosyksikko_id REAL PRIMARY KEY, organisaatio VARCHAR (9) REFERENCES organisaatio_y_tunnus, tulosyksikko_nimi VARCHAR)")
con.commit()
cur.executemany("INSERT INTO tulosyksikko VALUES(?, ?, ?)", df.loc[:, ["Tulosyksikkö", 'Y-tunnus', "Tulosyksikön nimi"]].drop_duplicates('Tulosyksikkö').values.tolist())
con.commit()
res = cur.execute("SELECT * FROM tulosyksikko LIMIT 3")
display(res.fetchall())
res = cur.execute("SELECT count(*) FROM tulosyksikko")
print (f"*****  TULOSYKSIKKÖ: {res.fetchall()[0][0]} rows inserted  *****\n\n")

# CREATE AND FILL TABLE vastuuyksikko
cur.execute("DROP TABLE IF EXISTS vastuuyksikko")
cur.execute("CREATE TABLE vastuuyksikko (vastuuyksikko_id INT PRIMARY KEY, organisaatio REFERENCES organisaatio_y_tunnus, vastuuyksikko_nimi VARCHAR)")
con.commit()
cur.executemany("INSERT INTO vastuuyksikko VALUES(?, ?, ?)", df.loc[:, ["Vastuuyksikkö", 'Y-tunnus', "Vastuuyksikön nimi"]].drop_duplicates('Vastuuyksikkö').values.tolist())
con.commit()
res = cur.execute("SELECT * FROM vastuuyksikko LIMIT 3")
display(res.fetchall())
res = cur.execute("SELECT count(*) FROM vastuuyksikko")
print (f"*****  VASTUUYKSIKKÖ: {res.fetchall()[0][0]} rows inserted  *****\n\n")

# CREATE AND FILL TABLE tiliryhma
cur.execute("DROP TABLE IF EXISTS tiliryhma")
cur.execute("CREATE TABLE tiliryhma (tiliryhma_id VARCHAR PRIMARY KEY, tiliryhma_nimi VARCHAR)")
con.commit()
cur.executemany("INSERT INTO tiliryhma VALUES(?, ?)", df.loc[:, ["Tiliryhmä", "Tiliryhmän nimi"]].drop_duplicates().values.tolist())
con.commit()
res = cur.execute("SELECT * FROM tiliryhma LIMIT 3")
display(res.fetchall())
res = cur.execute("SELECT count(*) FROM tiliryhma")
print (f"*****  TILIRYHMÄ: {res.fetchall()[0][0]} rows inserted  *****\n\n")

# CREATE AND FILL TABLE tili
cur.execute("DROP TABLE IF EXISTS tili")
cur.execute("CREATE TABLE tili (tilinumero INT PRIMARY KEY, tiliryhma REFERENCES tiliryhma_id, tili_nimi VARCHAR)")
con.commit()
cur.executemany("INSERT INTO tili VALUES(?, ?, ?)", df.loc[:, ["Tilin numero", 'Tiliryhmä', "Tilin nimi"]].drop_duplicates('Tilin numero').values.tolist())
con.commit()
res = cur.execute("SELECT * FROM tili LIMIT 3")
display(res.fetchall())
res = cur.execute("SELECT count(*) FROM tili")
print (f"*****  TILI: {res.fetchall()[0][0]} rows inserted  *****\n\n")

# CREATE AND FILL TABLE toimittaja
cur.execute("DROP TABLE IF EXISTS toimittaja")
cur.execute("CREATE TABLE toimittaja (toimittaja_y_tunnus VARCHAR(9) PRIMARY KEY, toimittaja_nimi VARCHAR, toimittaja_maakoodi VARCHAR(3))")
con.commit()
cur.executemany("INSERT INTO toimittaja VALUES(?, ?, ?)", df.loc[:, ["Toimittajan        y-tunnus", 'Toimittajan nimi', "Toimittajan maakoodi"]].drop_duplicates('Toimittajan        y-tunnus').values.tolist())
con.commit()
res = cur.execute("SELECT * FROM toimittaja LIMIT 3")
display(res.fetchall())
res = cur.execute("SELECT count(*) FROM toimittaja")
print (f"*****  TOIMITTAJA: {res.fetchall()[0][0]} rows inserted  *****\n\n")

# CREATE AND FILL TABLE tilaus
cur.execute("DROP TABLE IF EXISTS tilaus")
cur.execute("CREATE TABLE tilaus (tili REFERENCES tili_id, toimittaja REFERENCES toimittaja_y_tunnus, tulosyksikko REFERENCES tulosyksikko_id,\
             vastuuyksikko REFERENCES vastuuyksikko_id, tilaus_palveluluokka REAL, tilaus_laskunpaivays TEXT, tilaus_tositenumero INT,\
             tilaus_ostotilausnumero INT, tilaus_sopimusnumero INT, tilaus_tositepaivays TEXT, tilaus_laskunnumero INT, tilaus_alvnumero VARCHAR,\
             tilaus_netto_summa REAL, tilaus_alv_summa REAL, tilaus_kokonaissumma REAL)")
con.commit()
cur.executemany("INSERT INTO tilaus VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)",
                df.loc[:, ["Tilin numero", 'Toimittajan        y-tunnus', "Tulosyksikkö", "Vastuuyksikkö", "Palveluluokka", "Laskun päiväys",
                "Tosite numero", "Ostotilaus numero", "Sopimus numero", "Tosite päivämäärä", "Laskun numero", "ALV-rekisterinumero",
                "Netto summa", "Alv summa", "Kokonais summa"]].values.tolist())
con.commit()
res = cur.execute("SELECT * FROM tilaus LIMIT 1")
display(res.fetchall())
res = cur.execute("SELECT count(*) FROM tilaus")
print (f"*****  TILAUS: {res.fetchall()[0][0]} rows inserted  *****\n\n")
# Out:
#    Palveluluokka Laskun päiväys  Tosite numero  Ostotilaus numero  \
# 0         5501.0     24.03.2022          26462                NaN
# 1         9999.0     24.03.2022          26462                NaN
# 2         5501.0     01.01.2022          23256                NaN
#
#    Sopimus numero Tosite päivämäärä Laskun numero Tiliryhmä  \
# 0             NaN        24.03.2022  000000001074      T457
# 1             NaN        24.03.2022  000000001074     A1760
# 2             NaN        01.01.2022  000000008927      T480
#
#                   Tiliryhmän nimi  Tilin numero                  Tilin nimi  \
# 0  LÄMMITYS, SÄHKÖ, KAASU JA VESI        457020                       Sähkö
# 1    MUUT SAAMISET, LYHYTAIKAISET        176024  Alv-saamiset, palautus 24%
# 2                         VUOKRAT        480020        Toimitilojen vuokrat
#
#                 Toimittajan nimi Toimittajan maakoodi  \
# 0  KIINTEISTÖ OY PASILANRAITIO 5                   FI
# 1  KIINTEISTÖ OY PASILANRAITIO 5                   FI
# 2            HENRY INVESTMENT OY                   FI
#
#   Toimittajan        y-tunnus ALV-rekisterinumero  Netto summa  Alv summa  \
# 0                   0550836-4          FI05508364       290.24      69.66
# 1                   0550836-4          FI05508364          NaN      69.66
# 2                   2922998-4          FI29229984     14627.13    3510.51
#
#    Kokonais summa
# 0          359.90
# 1           69.66
# 2        18137.64
# [('1567535-0', 'HUS-kuntayhtymä')]
# *****  ORGANISAATIO: 1 rows inserted  *****
# [(700.0, '1567535-0', 'TILAKESKUKSEN HALLINTO'),
#  (710.0, '1567535-0', 'YHTYMÄHALLINTO'),
#  (777.0, '1567535-0', 'MONIPALVELUALUE 5')]
# *****  TULOSYKSIKKÖ: 28 rows inserted  *****
# [(7002018, '1567535-0', 'Vuokratilat, Helsinki'),
#  (7103002, '1567535-0', 'Tasekirjaukset'),
#  (7770003, '1567535-0', 'Ostopalvelut monipalvelualue 5, Ruokapalvelut')]
# *****  VASTUUYKSIKKÖ: 89 rows inserted  *****
# [('T457', 'LÄMMITYS, SÄHKÖ, KAASU JA VESI'),
#  ('A1760', 'MUUT SAAMISET, LYHYTAIKAISET'),
#  ('T480', 'VUOKRAT')]
# *****  TILIRYHMÄ: 25 rows inserted  *****
# [(457020, 'T457', 'Sähkö'),
#  (176024, 'A1760', 'Alv-saamiset, palautus 24%'),
#  (480020, 'T480', 'Toimitilojen vuokrat')]
# *****  TILI: 44 rows inserted  *****
# [('0550836-4', 'KIINTEISTÖ OY PASILANRAITIO 5', 'FI'),
#  ('2922998-4', 'HENRY INVESTMENT OY', 'FI'),
#  ('2768040-5', 'TIKKURILA-GRILLI OY', 'FI')]
# *****  TOIMITTAJA: 34 rows inserted  *****
# [(457020,
#   '0550836-4',
#   700.0,
#   7002018,
#   5501.0,
#   '24.03.2022',
#   26462,
#   None,
#   None,
#   '24.03.2022',
#   1074,
#   'FI05508364',
#   290.24,
#   69.66,
#   359.9)]
# *****  TILAUS: 1000 rows inserted  *****

# %%
#
# some validation for data tables and their integrity
#

# puuttuvia toimittaja tai tulosyksikkotietoja
print(f"{df['Toimittajan        y-tunnus'].isna().sum()} rivistä puuttuu toimittaja")
print(f"{df['Tulosyksikkö'].isna().sum()} rivistä puuttuu tulosyksikkö")

# Check that joining tables return correct number of rows
sql = "SELECT count (tilaus_tositenumero)\
       FROM tilaus, tili, tiliryhma, toimittaja, vastuuyksikko, tulosyksikko, organisaatio\
       WHERE tilaus.tili = tilinumero AND tili.tiliryhma = tiliryhma_id AND tilaus.toimittaja = toimittaja_y_tunnus\
       AND vastuuyksikko = vastuuyksikko_id AND tulosyksikko = tulosyksikko_id\
       AND tulosyksikko.organisaatio = organisaatio_y_tunnus AND vastuuyksikko.organisaatio = organisaatio_y_tunnus"
res = cur.execute(sql)
print(f"{res.fetchall()[0][0]} tietokannan muodostamassa liitoksessa täydelliset tiedot")

# test join query
sql = "SELECT tili, tili_nimi, tiliryhma_nimi, toimittaja_nimi, vastuuyksikko_nimi, tulosyksikko_nimi, organisaatio_nimi\
       FROM tilaus, tili, tiliryhma, toimittaja, vastuuyksikko, tulosyksikko, organisaatio\
       WHERE tili = tilinumero AND tiliryhma = tiliryhma_id AND toimittaja = toimittaja_y_tunnus\
       AND vastuuyksikko = vastuuyksikko_id AND tulosyksikko = tulosyksikko_id\
       AND tulosyksikko.organisaatio = organisaatio_y_tunnus AND vastuuyksikko.organisaatio = organisaatio_y_tunnus LIMIT 3"
res = cur.execute(sql)
display(res.fetchall())
# Out:
# 11 rivistä puuttuu toimittaja
# 10 rivistä puuttuu tulosyksikkö
# 979 tietokannan muodostamassa liitoksessa täydelliset tiedot
# [(457020,
#   'Sähkö',
#   'LÄMMITYS, SÄHKÖ, KAASU JA VESI',
#   'KIINTEISTÖ OY PASILANRAITIO 5',
#   'Vuokratilat, Helsinki',
#   'TILAKESKUKSEN HALLINTO',
#   'HUS-kuntayhtymä'),
#  (176024,
#   'Alv-saamiset, palautus 24%',
#   'MUUT SAAMISET, LYHYTAIKAISET',
#   'KIINTEISTÖ OY PASILANRAITIO 5',
#   'Tasekirjaukset',
#   'YHTYMÄHALLINTO',
#   'HUS-kuntayhtymä'),
#  (480020,
#   'Toimitilojen vuokrat',
#   'VUOKRAT',
#   'HENRY CAPITAL OY',
#   'Vuokratilat, Helsinki',
#   'TILAKESKUKSEN HALLINTO',
#   'HUS-kuntayhtymä')]

# %% [markdown]
# Finally, try to perform the change of name from 'HENRY INVESTMENT OY' to HENRY CAPITAL OY'. How many rows do you need to change?

# %%
# your code here

# change toimittajan nimi
update_sql = "UPDATE toimittaja SET toimittaja_nimi = ? WHERE toimittaja_nimi = ?"
cur.execute(update_sql, (new_name, old_name))
con.commit()

res = cur.execute("select changes(),total_changes()");
print(f"\n\n... {res.fetchall()[0][0]} rows updated!\n\n")
# Out:
# ... 1 rows updated!

# %% [markdown]
# BONUS: using your normalized tables, for each unit ('tulosyksikkö') figure out which provider ('toimittaja') has billed highest cost during the month of January in 2022, and how much the total bill sum is.

# %% [markdown]
# # your code here

# %%
# query 5 biggest billers
sql = "SELECT toimittaja_nimi, CAST(SUM(tilaus_kokonaissumma) AS INT) AS maksettu\
       FROM tilaus, toimittaja\
       WHERE toimittaja = toimittaja_y_tunnus\
       GROUP BY toimittaja_nimi ORDER BY maksettu DESC LIMIT 5"
res = cur.execute(sql)
print ("*****  5 HIGHEST BILLERS IN ALL DATA  *****")
display(res.fetchall())

# query 5 biggest billers in january 2022
sql = "SELECT toimittaja_nimi, CAST(SUM(tilaus_kokonaissumma) AS INT) AS maksettu\
       FROM tilaus, toimittaja\
       WHERE toimittaja = toimittaja_y_tunnus AND tilaus_laskunpaivays LIKE '%01.2022'\
       GROUP BY toimittaja_nimi ORDER BY maksettu DESC LIMIT 5"
res = cur.execute(sql)
print ("\n\n*****  5 HIGHEST BILLERS IN JANUARY 2022  *****")
display(res.fetchall())
# Out:
# *****  5 HIGHEST BILLERS IN ALL DATA  *****
# [('STERIPOLAR OY', 328028),
#  ('BISNODE MARKETING OY', 272607),
#  ('HENRY CAPITAL OY', 98865),
#  ('VAASAN SAIRAANHOITOPIIRIN KUNTAYHTYMÄ', 40831),
#  ('ELISA VIDERA OY', 8151)]
# *****  5 HIGHEST BILLERS IN JANUARY 2022  *****
# [('STERIPOLAR OY', 200016),
#  ('BISNODE MARKETING OY', 77162),
#  ('VAASAN SAIRAANHOITOPIIRIN KUNTAYHTYMÄ', 40732),
#  ('HENRY CAPITAL OY', 32452),
#  ('LEINONEN ARI', 3381)]
